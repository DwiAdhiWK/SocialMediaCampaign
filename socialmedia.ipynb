# %% [markdown]
# # Introduction
#
# ___
#
# Projek ini dibuat untuk melakukan analisis terhadap penggunaan platform sosial media utuk mengotimisasikan jenis promosi.
# ___

# %% [markdown]
# # Data Preperation

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %%
df = pd.read_csv("social_media_campaign_db.csv")
df
# Out:
#                  Date             Platform  Campaign   Reach  Impressions  \
# 2025-01-08   Facebook       Product Launch     14474   22708         2356
# 2025-01-08     TikTok       Product Launch     18545  119547         2555
# 2025-01-15  Instagram  Brand Collaboration     31736   18111          553
# 2025-01-15     TikTok       Product Launch     11776  116893         4390
# 2025-01-22   Facebook       Product Launch     31309   54254         6280
# 2025-02-12  Instagram       Product Launch     43623    8802         3483
# 2025-02-19  Instagram       Product Launch     47941  113081         1316
# 2025-02-26  Instagram          Promo Month     60680   80656         5892
# 2025-02-26   Facebook  Brand Collaboration     17688   37306         4733
# 2025-03-12     TikTok            Awareness     49262   29671         6697
# 2025-03-12     TikTok          Promo Month     26976   87623         5723
# 2025-03-19   Facebook     Engagement Boost     78530  102742         6595
# ...
